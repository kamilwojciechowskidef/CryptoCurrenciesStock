# %%
import psycopg2
conn = psycopg2.connect(host="127.0.0.1", port=5432, dbname="cryptoetl",
user="postgres", password="postgres", sslmode="disable")
cur = conn.cursor(); cur.execute("SELECT 1"); print(cur.fetchone())
cur.close(); conn.close()
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[2], line 2
#       1 import psycopg2
# ----> 2 conn = psycopg2.connect(host="127.0.0.1", port=5432, dbname="cryptoetl",
#       3 user="postgres", password="postgres", sslmode="disable")
#       4 cur = conn.cursor(); cur.execute("SELECT 1"); print(cur.fetchone())
#       5 cur.close(); conn.close()
#
# File c:\Users\kamil\Desktop\CryptoCurrenciesStock\.venv\Lib\site-packages\psycopg2\__init__.py:122, in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     119     kwasync['async_'] = kwargs.pop('async_')
#     121 dsn = _ext.make_dsn(dsn, **kwargs)
# --> 122 conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     123 if cursor_factory is not None:
#     124     conn.cursor_factory = cursor_factory
#
# ...
